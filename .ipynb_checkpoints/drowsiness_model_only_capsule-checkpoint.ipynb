# %%
import socket
import struct
import zlib
import tempfile
import tensorflow as tf
import numpy as np
from tqdm import tqdm
from sklearn.metrics import classification_report
# from tensorflow.keras.saving import register_keras_serializable
from tensorflow.keras import layers, initializers, backend as K
from sklearn.metrics import confusion_matrix, accuracy_score
from cryptography.fernet import Fernet
import base64
import hashlib

# %%
from tensorflow.keras import layers, initializers, backend as K

# **Custom Capsule Layers**
class Length(layers.Layer):
    def call(self, inputs, **kwargs):
        return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

    def compute_output_shape(self, input_shape):
        return input_shape[:-1]

class CapsuleLayer(layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        self.input_num_capsule = input_shape[1]
        self.input_dim_capsule = input_shape[2]
        self.W = self.add_weight(
            shape=[1, self.input_num_capsule, self.num_capsule, self.dim_capsule, self.input_dim_capsule],
            initializer=initializers.glorot_uniform(),
            name='W'
        )
        self.built = True

    def call(self, inputs):
        inputs_expand = K.expand_dims(K.expand_dims(inputs, 2), 2)
        W_tiled = K.tile(self.W, [K.shape(inputs)[0], 1, 1, 1, 1])
        inputs_hat = tf.squeeze(tf.matmul(W_tiled, inputs_expand, transpose_b=True), axis=-1)
        b = tf.zeros(shape=[K.shape(inputs)[0], self.input_num_capsule, self.num_capsule])

        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=2)
            outputs = tf.reduce_sum(inputs_hat * K.expand_dims(c, -1), axis=1)
            if i < self.routings - 1:
                b += tf.reduce_sum(inputs_hat * K.expand_dims(c, -1), axis=-1)
        return outputs

# **Build MobileNet + Capsule Model**
class MobileNetCapsNet:
    def __init__(self, input_shape=(224, 224, 3)):
        self.input_shape = input_shape
        self.model = self._build_model()

    def _build_model(self):
        base_model = tf.keras.applications.MobileNetV2(
            input_shape=self.input_shape,
            include_top=False,
            weights='imagenet'
        )
        base_model.trainable = False  # Freeze MobileNet

        x = base_model.output
        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Reshape((-1, 64))(x)
        x = CapsuleLayer(num_capsule=2, dim_capsule=8, routings=1)(x)
        outputs = Length()(x)

        return tf.keras.Model(inputs=base_model.input, outputs=outputs)

# **Margin Loss Function**
def margin_loss(y_true, y_pred):
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=2)
    L = y_true * tf.square(tf.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * tf.square(tf.maximum(0., y_pred - 0.1))
    return tf.reduce_mean(tf.reduce_sum(L, axis=1))

# %%
# custom_objects = {
#     'CapsuleLayer': CapsuleLayer,
#     'PrimaryCap': PrimaryCap,
#     'squash': squash,
#     'capsule_length': capsule_length,
#     'margin_loss': margin_loss,  # include if you're using a custom margin loss

# }
model=tf.keras.models.load_model(r"D:\Major Project\Final Proper\drowsiness_lesser_india_plus_eye.keras",custom_objects={"CapsuleLayer": CapsuleLayer,"Length":Length,"margin_loss":margin_loss})
# Out:
# WARNING:tensorflow:From D:\Major Project\venv\lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
print(model.output_shape)
# Out:
# (None, 4)

# %%
import os
import cv2

def extract_frames(video_path, output_folder, frame_interval=10):
    os.makedirs(output_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    
    frame_count = 0
    saved_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            frame_path = os.path.join(output_folder, f"frame_{saved_count}.jpg")
            cv2.imwrite(frame_path, frame)  # Save raw frame
            saved_count += 1

        frame_count += 1
    
    cap.release()
    cv2.destroyAllWindows()
    print(f"Extracted {saved_count} frames to {output_folder}")

# Run it on your video
video_path = r"D:\Major Project\Final Proper\Video_Data\Fold1_part1\02\5.MOV"  # Change this to your actual video path
output_folder = "american_extracted_frames"
extract_frames(video_path, output_folder)
# Out:
# Extracted 1811 frames to american_extracted_frames

# %%
import os
import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf
import shutil

# **Load Your Pretrained Model**
#model = tf.keras.models.load_model("your_model_path.h5")  # Change to your model path

# **Define Class Labels**
CLASS_LABELS = {
    0: "Eyes Closed",  # Drowsy
    1: "Happy",        # Non-Drowsy
    2: "Neutral",      # Non-Drowsy
    3: "Yawning"       # Drowsy
}

# **Setup MediaPipe Face Mesh**
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False, max_num_faces=1, min_detection_confidence=0.5)

# **Dataset Paths**
input_folder = "american_extracted_frames"
drowsy_folder = "drowsy"
non_drowsy_folder = "non_drowsy"
uncertain_folder = "uncertain"

os.makedirs(drowsy_folder, exist_ok=True)
os.makedirs(non_drowsy_folder, exist_ok=True)
os.makedirs(uncertain_folder, exist_ok=True)

# **Preprocessing Function for Model**
# **Preprocessing Function for Model (Now Includes Rotation)**
def preprocess_image(image_path, target_size=(224, 224), rotate=True):
    img = cv2.imread(image_path)
    if img is None:
        return None  # Skip if the image is unreadable

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # **Rotate Image 90 Degrees Clockwise (if needed)**
    img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

    img = cv2.resize(img, target_size)
    img = img / 255.0  # Normalize
    return np.expand_dims(img, axis=0)  # Add batch dimension


# **Function to Check Head Orientation**
def get_head_tilt(face_landmarks, image_width):
    left_cheek = face_landmarks.landmark[234].x * image_width
    right_cheek = face_landmarks.landmark[454].x * image_width
    face_center = (left_cheek + right_cheek) / 2

    if face_center < image_width * 0.35:
        return "Right"
    elif face_center > image_width * 0.65:
        return "Left"
    else:
        return "Center"

# **Function to Process Image and Classify Drowsiness**
def classify_drowsiness(img, img_path):
    h, w, _ = img.shape
    rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(rgb_img)

    avg_eye_opening = None
    mouth_opening = None
    head_orientation = "Center"

    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            head_orientation = get_head_tilt(face_landmarks, w)

            # **Extract Eye Landmarks**
            left_eye_top = face_landmarks.landmark[159]
            left_eye_bottom = face_landmarks.landmark[145]
            right_eye_top = face_landmarks.landmark[386]
            right_eye_bottom = face_landmarks.landmark[374]

            if head_orientation == "Right":
                avg_eye_opening = (left_eye_bottom.y - left_eye_top.y) * h
            elif head_orientation == "Left":
                avg_eye_opening = (right_eye_bottom.y - right_eye_top.y) * h
            else:
                avg_eye_opening = ((left_eye_bottom.y - left_eye_top.y) + (right_eye_bottom.y - right_eye_top.y)) * h / 2

            # **Mouth Landmarks**
            upper_lip_top = face_landmarks.landmark[13]
            lower_lip_bottom = face_landmarks.landmark[14]
            mouth_opening = (lower_lip_bottom.y - upper_lip_top.y) * h

    # **Preprocess Image for Model**
    img_array = preprocess_image(img_path)

    # **Model Prediction**
    prediction = model.predict(img_array)
    class_id = np.argmax(prediction)
    confidence = round(max(prediction[0]) * 100, 2)

    # **Fusion of MediaPipe & Model Results**
    eye_threshold = 5
    mouth_threshold = 15

    if avg_eye_opening is not None and avg_eye_opening < eye_threshold:
        detected_drowsy = True
    elif mouth_opening is not None and mouth_opening > mouth_threshold:
        detected_drowsy = True
    else:
        detected_drowsy = class_id in [0, 3]

    # **Final Decision**
    if detected_drowsy:
        target_folder = drowsy_folder
        status = "Drowsy"
        color = (0, 0, 255)
    else:
        target_folder = non_drowsy_folder
        status = "Non-Drowsy"
        color = (0, 255, 0)

    # **Store Image in Folder Based on Confidence**
    if confidence >= 75:
        print(f"✅ Image: {img_path} → {CLASS_LABELS[class_id]} ({status}) (Confidence: {confidence}%)")
        shutil.copy2(img_path, os.path.join(target_folder, os.path.basename(img_path)))
    else:
        print(f"⚠️ Uncertain: {img_path} (Confidence: {confidence}%) - Below threshold")
        shutil.copy2(img_path, os.path.join(uncertain_folder, os.path.basename(img_path)))

# **Process All Images in Folder**
for filename in os.listdir(input_folder):
    img_path = os.path.join(input_folder, filename)
    if not filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
        continue

    img = cv2.imread(img_path)
    if img is not None:
        classify_drowsiness(img, img_path)
    else:
        print(f"⚠️ Skipping {filename} (Could not read image)")

print("\n✅ Classification completed! High-confidence images sorted, uncertain ones stored separately.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_0.jpg → Happy (Drowsy) (Confidence: 340.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1.jpg → Happy (Drowsy) (Confidence: 380.84%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_10.jpg → Happy (Drowsy) (Confidence: 410.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_100.jpg → Happy (Drowsy) (Confidence: 407.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1000.jpg → Yawning (Drowsy) (Confidence: 403.9%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1001.jpg → Yawning (Drowsy) (Confidence: 437.8%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1002.jpg → Yawning (Drowsy) (Confidence: 403.35%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1003.jpg → Yawning (Drowsy) (Confidence: 417.5%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1004.jpg → Yawning (Drowsy) (Confidence: 395.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1005.jpg → Yawning (Drowsy) (Confidence: 365.35%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1006.jpg → Yawning (Drowsy) (Confidence: 382.16%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1007.jpg → Yawning (Drowsy) (Confidence: 380.59%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1008.jpg → Yawning (Drowsy) (Confidence: 372.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1009.jpg → Yawning (Drowsy) (Confidence: 357.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_101.jpg → Happy (Drowsy) (Confidence: 411.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1010.jpg → Yawning (Drowsy) (Confidence: 362.04%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1011.jpg → Yawning (Drowsy) (Confidence: 359.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1012.jpg → Yawning (Drowsy) (Confidence: 371.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1013.jpg → Yawning (Drowsy) (Confidence: 350.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1014.jpg → Yawning (Drowsy) (Confidence: 359.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# ✅ Image: american_extracted_frames\frame_1015.jpg → Yawning (Drowsy) (Confidence: 379.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1016.jpg → Yawning (Drowsy) (Confidence: 389.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1017.jpg → Yawning (Drowsy) (Confidence: 382.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1018.jpg → Yawning (Drowsy) (Confidence: 421.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1019.jpg → Yawning (Drowsy) (Confidence: 396.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_102.jpg → Happy (Drowsy) (Confidence: 409.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1020.jpg → Yawning (Drowsy) (Confidence: 392.22%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1021.jpg → Yawning (Drowsy) (Confidence: 398.24%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1022.jpg → Yawning (Drowsy) (Confidence: 298.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1023.jpg → Happy (Drowsy) (Confidence: 312.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1024.jpg → Happy (Drowsy) (Confidence: 361.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1025.jpg → Happy (Drowsy) (Confidence: 361.67%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1026.jpg → Happy (Drowsy) (Confidence: 411.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1027.jpg → Happy (Drowsy) (Confidence: 382.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# ✅ Image: american_extracted_frames\frame_1028.jpg → Happy (Drowsy) (Confidence: 375.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1029.jpg → Happy (Drowsy) (Confidence: 364.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_103.jpg → Happy (Drowsy) (Confidence: 399.23%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1030.jpg → Happy (Drowsy) (Confidence: 421.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1031.jpg → Yawning (Drowsy) (Confidence: 382.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1032.jpg → Yawning (Drowsy) (Confidence: 339.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1033.jpg → Happy (Drowsy) (Confidence: 316.67%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1034.jpg → Yawning (Drowsy) (Confidence: 386.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1035.jpg → Yawning (Drowsy) (Confidence: 376.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1036.jpg → Yawning (Drowsy) (Confidence: 391.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1037.jpg → Happy (Drowsy) (Confidence: 390.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1038.jpg → Happy (Drowsy) (Confidence: 405.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1039.jpg → Happy (Drowsy) (Confidence: 405.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_104.jpg → Happy (Drowsy) (Confidence: 406.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1040.jpg → Happy (Drowsy) (Confidence: 387.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1041.jpg → Happy (Drowsy) (Confidence: 373.59%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1042.jpg → Happy (Drowsy) (Confidence: 385.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1043.jpg → Happy (Drowsy) (Confidence: 363.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Image: american_extracted_frames\frame_1044.jpg → Happy (Drowsy) (Confidence: 394.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1045.jpg → Happy (Drowsy) (Confidence: 406.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ✅ Image: american_extracted_frames\frame_1046.jpg → Happy (Drowsy) (Confidence: 409.5%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1047.jpg → Happy (Drowsy) (Confidence: 375.85%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Image: american_extracted_frames\frame_1048.jpg → Happy (Drowsy) (Confidence: 414.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1049.jpg → Happy (Drowsy) (Confidence: 393.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_105.jpg → Happy (Drowsy) (Confidence: 419.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1050.jpg → Happy (Drowsy) (Confidence: 394.85%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1051.jpg → Happy (Drowsy) (Confidence: 381.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1052.jpg → Happy (Drowsy) (Confidence: 377.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1053.jpg → Happy (Drowsy) (Confidence: 377.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1054.jpg → Happy (Drowsy) (Confidence: 392.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1055.jpg → Happy (Drowsy) (Confidence: 385.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1056.jpg → Happy (Drowsy) (Confidence: 375.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1057.jpg → Happy (Drowsy) (Confidence: 375.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1058.jpg → Happy (Drowsy) (Confidence: 379.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1059.jpg → Happy (Drowsy) (Confidence: 374.82%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_106.jpg → Happy (Drowsy) (Confidence: 390.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1060.jpg → Happy (Drowsy) (Confidence: 352.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# ✅ Image: american_extracted_frames\frame_1061.jpg → Yawning (Drowsy) (Confidence: 359.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1062.jpg → Happy (Drowsy) (Confidence: 361.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Image: american_extracted_frames\frame_1063.jpg → Happy (Drowsy) (Confidence: 359.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# ✅ Image: american_extracted_frames\frame_1064.jpg → Yawning (Drowsy) (Confidence: 344.16%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ✅ Image: american_extracted_frames\frame_1065.jpg → Happy (Drowsy) (Confidence: 347.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ✅ Image: american_extracted_frames\frame_1066.jpg → Yawning (Drowsy) (Confidence: 352.22%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1067.jpg → Happy (Drowsy) (Confidence: 363.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1068.jpg → Happy (Drowsy) (Confidence: 379.77%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1069.jpg → Happy (Drowsy) (Confidence: 384.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_107.jpg → Happy (Drowsy) (Confidence: 403.8%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1070.jpg → Happy (Drowsy) (Confidence: 392.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1071.jpg → Happy (Drowsy) (Confidence: 413.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1072.jpg → Happy (Drowsy) (Confidence: 403.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1073.jpg → Happy (Drowsy) (Confidence: 398.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1074.jpg → Happy (Drowsy) (Confidence: 384.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1075.jpg → Happy (Drowsy) (Confidence: 371.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1076.jpg → Happy (Drowsy) (Confidence: 384.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1077.jpg → Happy (Drowsy) (Confidence: 381.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Image: american_extracted_frames\frame_1078.jpg → Happy (Drowsy) (Confidence: 382.17%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Image: american_extracted_frames\frame_1079.jpg → Happy (Drowsy) (Confidence: 389.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_108.jpg → Happy (Drowsy) (Confidence: 411.53%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1080.jpg → Happy (Drowsy) (Confidence: 393.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1081.jpg → Happy (Drowsy) (Confidence: 394.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1082.jpg → Happy (Drowsy) (Confidence: 389.35%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ✅ Image: american_extracted_frames\frame_1083.jpg → Happy (Drowsy) (Confidence: 380.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1084.jpg → Happy (Drowsy) (Confidence: 371.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1085.jpg → Happy (Drowsy) (Confidence: 375.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1086.jpg → Happy (Drowsy) (Confidence: 380.84%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Image: american_extracted_frames\frame_1087.jpg → Happy (Drowsy) (Confidence: 376.75%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Image: american_extracted_frames\frame_1088.jpg → Happy (Drowsy) (Confidence: 387.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1089.jpg → Happy (Drowsy) (Confidence: 380.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_109.jpg → Happy (Drowsy) (Confidence: 390.22%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Image: american_extracted_frames\frame_1090.jpg → Happy (Drowsy) (Confidence: 359.87%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1091.jpg → Happy (Drowsy) (Confidence: 364.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ✅ Image: american_extracted_frames\frame_1092.jpg → Happy (Drowsy) (Confidence: 385.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1093.jpg → Happy (Drowsy) (Confidence: 385.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Image: american_extracted_frames\frame_1094.jpg → Happy (Drowsy) (Confidence: 385.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Image: american_extracted_frames\frame_1095.jpg → Happy (Drowsy) (Confidence: 380.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ✅ Image: american_extracted_frames\frame_1096.jpg → Yawning (Drowsy) (Confidence: 368.68%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1097.jpg → Yawning (Drowsy) (Confidence: 367.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ✅ Image: american_extracted_frames\frame_1098.jpg → Yawning (Drowsy) (Confidence: 357.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Image: american_extracted_frames\frame_1099.jpg → Yawning (Drowsy) (Confidence: 348.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_11.jpg → Happy (Drowsy) (Confidence: 389.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_110.jpg → Happy (Drowsy) (Confidence: 399.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Image: american_extracted_frames\frame_1100.jpg → Happy (Drowsy) (Confidence: 356.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1101.jpg → Yawning (Drowsy) (Confidence: 363.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1102.jpg → Yawning (Drowsy) (Confidence: 364.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1103.jpg → Yawning (Drowsy) (Confidence: 363.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Image: american_extracted_frames\frame_1104.jpg → Yawning (Drowsy) (Confidence: 361.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1105.jpg → Yawning (Drowsy) (Confidence: 347.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ✅ Image: american_extracted_frames\frame_1106.jpg → Yawning (Drowsy) (Confidence: 362.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1107.jpg → Yawning (Drowsy) (Confidence: 367.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1108.jpg → Happy (Drowsy) (Confidence: 355.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1109.jpg → Happy (Drowsy) (Confidence: 371.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_111.jpg → Happy (Drowsy) (Confidence: 411.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1110.jpg → Yawning (Drowsy) (Confidence: 388.04%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Image: american_extracted_frames\frame_1111.jpg → Yawning (Drowsy) (Confidence: 419.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1112.jpg → Yawning (Drowsy) (Confidence: 513.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Image: american_extracted_frames\frame_1113.jpg → Yawning (Drowsy) (Confidence: 469.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1114.jpg → Yawning (Drowsy) (Confidence: 544.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1115.jpg → Yawning (Drowsy) (Confidence: 539.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1116.jpg → Yawning (Drowsy) (Confidence: 438.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Image: american_extracted_frames\frame_1117.jpg → Yawning (Drowsy) (Confidence: 521.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_1118.jpg → Yawning (Drowsy) (Confidence: 457.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# ✅ Image: american_extracted_frames\frame_1119.jpg → Yawning (Drowsy) (Confidence: 409.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Image: american_extracted_frames\frame_112.jpg → Happy (Drowsy) (Confidence: 399.06%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Image: american_extracted_frames\frame_1120.jpg → Yawning (Drowsy) (Confidence: 407.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1121.jpg → Yawning (Drowsy) (Confidence: 398.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ✅ Image: american_extracted_frames\frame_1122.jpg → Yawning (Drowsy) (Confidence: 382.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1123.jpg → Yawning (Drowsy) (Confidence: 375.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Image: american_extracted_frames\frame_1124.jpg → Yawning (Drowsy) (Confidence: 394.77%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1125.jpg → Yawning (Drowsy) (Confidence: 388.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Image: american_extracted_frames\frame_1126.jpg → Yawning (Drowsy) (Confidence: 420.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Image: american_extracted_frames\frame_1127.jpg → Yawning (Drowsy) (Confidence: 401.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# ✅ Image: american_extracted_frames\frame_1128.jpg → Yawning (Drowsy) (Confidence: 406.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Image: american_extracted_frames\frame_1129.jpg → Yawning (Drowsy) (Confidence: 422.1%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 141
#     139 img = cv2.imread(img_path)
#     140 if img is not None:
# --> 141     classify_drowsiness(img, img_path)
#     142 else:
#     143     print(f"⚠️ Skipping {filename} (Could not read image)")
#
# Cell In[7], line 100, in classify_drowsiness(img, img_path)
#      97 img_array = preprocess_image(img_path)
#      99 # **Model Prediction**
# --> 100 prediction = model.predict(img_array)
#     101 class_id = np.argmax(prediction)
#     102 confidence = round(max(prediction[0]) * 100, 2)
#
# File D:\Major Project\venv\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Major Project\venv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:560, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     558 callbacks.on_predict_batch_begin(step)
#     559 data = get_data(iterator)
# --> 560 batch_outputs = self.predict_function(data)
#     561 outputs = append_to_outputs(batch_outputs, outputs)
#     562 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File D:\Major Project\venv\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# class_indices = model.class_indices
# print(f"Class Indices from Model: {class_indices}")

# %%
# import cv2
# import numpy as np
# import tensorflow as tf


# # Image preprocessing function
# def preprocess_image(image_path, target_size=(224, 224)):
#     img = cv2.imread(image_path)  # Read the image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
#     img = cv2.resize(img, target_size)  # Resize to model input size
#     img = img / 255.0  # Normalize pixel values (0 to 1)
#     return np.expand_dims(img, axis=0)  # Add batch dimension

# # Function to classify a single image
# def classify_image(image_path, confidence_threshold=75):
#     img_array = preprocess_image(image_path)

#     # Predict using the model
#     prediction = model.predict(img_array)
#     class_id = np.argmax(prediction)  # Get the predicted class index
#     confidence = round(max(prediction[0]) * 100, 2)  # Get highest probability

#     # **Corrected Mapping: Closed Eyes (0) = Drowsy, Open Eyes (1) = Non-Drowsy**
#     label = "Drowsy 😴" if class_id == 0 else "Non-Drowsy 😃"

#     # Print result
#     print(f"🖼️ Image: {image_path}")
#     print(f"🔍 Prediction: {label} (Confidence: {confidence}%)")

#     # Return results
#     return {"image": image_path, "label": label, "confidence": confidence}

# # Test the function with an image
# image_path = r"D:\Major Project\Final Proper\Dataset\American\Drowsy\img_e_15341.jpg"# Change this to your image file path
# result = classify_image(image_path)

# %%
# import cv2
# import numpy as np
# import tensorflow as tf

# # **Define Class Labels (Matching Your Dataset)**
# CLASS_LABELS = {
#     0: "Eyes Closed",   # Drowsy (Mapped from "Eyeclose")
#     1: "Happy",         # Non-Drowsy
#     2: "Neutral",       # Non-Drowsy
#     3: "Yawning"        # Drowsy (Mapped from "Yawn")
# }

# # **Preprocess Image Before Prediction**
# def preprocess_image(image_path, target_size=(224, 224)):
#     img = cv2.imread(image_path)  # Read the image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
#     img = cv2.resize(img, target_size)  # Resize to match model input
#     img = img / 255.0  # Normalize pixel values (0 to 1)
#     return np.expand_dims(img, axis=0)  # Add batch dimension

# # **Classify Image Function**
# def classify_image(image_path):
#     img_array = preprocess_image(image_path)

#     # Predict using the model
#     prediction = model.predict(img_array)
#     class_id = np.argmax(prediction)  # Get the predicted class index
#     confidence = round(max(prediction[0])*10 , 2)  # Get highest probability

#     # Determine drowsiness status
#     if class_id in [0, 3]:  # Eyes Closed or Yawning
#         status = "Drowsy 😴"
#     else:  # Happy or Neutral
#         status = "Non-Drowsy 😃"

#     # Print result
#     print(f"🖼️ Image: {image_path}")
#     print(f"🔍 Prediction: {CLASS_LABELS[class_id]} ({status}) (Confidence: {confidence}%)")

#     # Return results
#     return {"image": image_path, "label": CLASS_LABELS[class_id], "status": status, "confidence": confidence}

# # **Example Usage**
# image_path = r"D:\Major Project\Dataset_Classified\non_drowsy\Drowsy (4458).jpg" # Change to your test image path
# result = classify_image(image_path)

# %%
#NOT USING MEDIAPIPE
# import os
# import cv2
# import numpy as np
# import tensorflow as tf
# import shutil


# # **Define Dataset Paths**
# input_folder = "D:/Major Project/Dataset"  # Root dataset folder
# drowsy_folder = "D:/Major Project/Dataset_Classified/drowsy"
# non_drowsy_folder = "D:/Major Project/Dataset_Classified/non_drowsy"
# uncertain_folder = "D:/Major Project/Dataset_Classified/uncertain"  # Low-confidence images

# # **Create Output Folders if They Don't Exist**
# os.makedirs(drowsy_folder, exist_ok=True)
# os.makedirs(non_drowsy_folder, exist_ok=True)
# os.makedirs(uncertain_folder, exist_ok=True)

# # **Class Labels Mapping (Based on Your Dataset)**
# CLASS_LABELS = {
#     0: "Eyes Closed",   # Drowsy
#     1: "Happy",         # Non-Drowsy
#     2: "Neutral",       # Non-Drowsy
#     3: "Yawning"        # Drowsy
# }

# # **Preprocessing Function**
# def preprocess_image(image_path, target_size=(224, 224)):
#     img = cv2.imread(image_path)
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img = cv2.resize(img, target_size)
#     img = img / 255.0  # Normalize
#     return np.expand_dims(img, axis=0)  # Add batch dimension

# # **Classify and Sort Images**
# CONFIDENCE_THRESHOLD = 75  # Confidence cutoff for certainty

# for subdir, _, files in os.walk(input_folder):
#     for filename in files:
#         img_path = os.path.join(subdir, filename)

#         # **Skip Non-Image Files**
#         if not filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
#             continue

#         img_array = preprocess_image(img_path)

#         # **Predict Using Model**
#         prediction = model.predict(img_array)
#         class_id = np.argmax(prediction)  # Get class index
#         confidence = round(max(prediction[0]) * 100, 2)  # Get highest probability

#         # **Determine Drowsiness Status**
#         if class_id in [0, 3]:  # Eyes Closed or Yawning
#             status = "Drowsy"
#             target_folder = drowsy_folder
#         else:  # Happy or Neutral
#             status = "Non-Drowsy"
#             target_folder = non_drowsy_folder

#         # **Sort Based on Confidence Level**
#         if confidence >= CONFIDENCE_THRESHOLD:
#             print(f"✅ {filename} → {CLASS_LABELS[class_id]} ({status}) (Confidence: {confidence}%)")
#             shutil.copy2(img_path, os.path.join(target_folder, filename))
#         else:
#             print(f"⚠️ Uncertain: {filename} (Confidence: {confidence}%) - Below threshold")
#             shutil.copy2(img_path, os.path.join(uncertain_folder, filename))

# print("\n✅ Classification completed! High-confidence images sorted, uncertain ones stored separately.")

# %% [markdown]
# ##USING MEDIAPIPE

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import shutil
import mediapipe as mp

# **Load MediaPipe Face Mesh**
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, min_detection_confidence=0.5)

# **Load Pretrained Model**
#model = tf.keras.models.load_model("D:/Major Project/your_model.h5")  # Update with actual model path

# **Define Dataset Paths**
input_folder = "D:/Major Project/Dataset"  # Root dataset folder
drowsy_folder = "D:/Major Project/Dataset_Classified/drowsy"
non_drowsy_folder = "D:/Major Project/Dataset_Classified/non_drowsy"
uncertain_folder = "D:/Major Project/Dataset_Classified/uncertain"  # Low-confidence images

# **Create Output Folders if They Don't Exist**
os.makedirs(drowsy_folder, exist_ok=True)
os.makedirs(non_drowsy_folder, exist_ok=True)
os.makedirs(uncertain_folder, exist_ok=True)

# **Class Labels Mapping (Based on Your Dataset)**
CLASS_LABELS = {
    0: "Eyes Closed",   # Drowsy
    1: "Happy",         # Non-Drowsy
    2: "Neutral",       # Non-Drowsy
    3: "Yawning"        # Drowsy
}

# **Preprocessing Function**
def preprocess_image(img, target_size=(224, 224)):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)
    img = img / 255.0  # Normalize
    return np.expand_dims(img, axis=0)  # Add batch dimension

# **Classify and Sort Images**
CONFIDENCE_THRESHOLD = 75  # Confidence cutoff for certainty

for subdir, _, files in os.walk(input_folder):
    for filename in files:
        img_path = os.path.join(subdir, filename)

        # **Skip Non-Image Files**
        if not filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            continue

        img = cv2.imread(img_path)
        if img is None:
            print(f"⚠️ Skipping {filename} (Could not read image)")
            continue

        h, w, _ = img.shape

        # **Detect face mesh using MediaPipe**
        rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = face_mesh.process(rgb_img)

        if results.multi_face_landmarks:
            for face_landmarks in results.multi_face_landmarks:
                # **Extract Eye Landmarks**
                left_eye_top = face_landmarks.landmark[159]
                left_eye_bottom = face_landmarks.landmark[145]
                right_eye_top = face_landmarks.landmark[386]
                right_eye_bottom = face_landmarks.landmark[374]

                left_eye_opening = int((left_eye_bottom.y - left_eye_top.y) * h)
                right_eye_opening = int((right_eye_bottom.y - right_eye_top.y) * h)

                # **Eye openness threshold**
                eye_threshold = 5  # Adjust based on testing
                avg_eye_opening = (left_eye_opening + right_eye_opening) / 2

                # **Extract Mouth Landmarks**
                upper_lip_top = face_landmarks.landmark[13]
                lower_lip_bottom = face_landmarks.landmark[14]

                mouth_opening = int((lower_lip_bottom.y - upper_lip_top.y) * h)

                # **Preprocess and Predict Using Model**
                img_array = preprocess_image(img)
                prediction = model.predict(img_array)
                class_id = np.argmax(prediction)  # Get class index
                confidence = round(max(prediction[0]) * 100, 2)  # Get highest probability

                # **Drowsiness Classification Logic**
                if avg_eye_opening < eye_threshold or class_id == 0:
                    status = "Drowsy"
                    target_folder = drowsy_folder
                elif mouth_opening > 15 and class_id == 3:
                    status = "Drowsy"
                    target_folder = drowsy_folder
                else:
                    status = "Non-Drowsy"
                    target_folder = non_drowsy_folder

                # **Sort Based on Confidence Level**
                if confidence >= CONFIDENCE_THRESHOLD:
                    print(f"✅ {filename} → {CLASS_LABELS[class_id]} ({status}) (Confidence: {confidence}%)")
                    shutil.copy2(img_path, os.path.join(target_folder, filename))
                else:
                    print(f"⚠️ Uncertain: {filename} (Confidence: {confidence}%) - Below threshold")
                    shutil.copy2(img_path, os.path.join(uncertain_folder, filename))
        else:
            print(f"🚫 No face detected in {filename}. Marking as uncertain.")
            shutil.copy2(img_path, os.path.join(uncertain_folder, filename))

print("\n✅ Classification completed! High-confidence images sorted, uncertain ones stored separately.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1).png → Yawning (Drowsy) (Confidence: 513.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (10).png → Yawning (Drowsy) (Confidence: 530.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (100).jpg → Happy (Non-Drowsy) (Confidence: 339.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1000).jpg → Yawning (Drowsy) (Confidence: 838.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1001).jpg → Yawning (Non-Drowsy) (Confidence: 821.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1002).jpg → Yawning (Drowsy) (Confidence: 728.13%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1003).jpg → Yawning (Non-Drowsy) (Confidence: 742.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1004).jpg → Yawning (Non-Drowsy) (Confidence: 731.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1005).jpg → Yawning (Non-Drowsy) (Confidence: 814.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1006).jpg → Yawning (Drowsy) (Confidence: 746.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1007).jpg → Yawning (Non-Drowsy) (Confidence: 963.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1008).jpg → Yawning (Non-Drowsy) (Confidence: 676.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1009).jpg → Yawning (Non-Drowsy) (Confidence: 543.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (101).jpg → Happy (Non-Drowsy) (Confidence: 340.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ✅ Drowsy (1010).jpg → Yawning (Drowsy) (Confidence: 719.31%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1011).jpg → Yawning (Non-Drowsy) (Confidence: 569.68%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1012).jpg → Yawning (Non-Drowsy) (Confidence: 578.13%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1013).jpg → Yawning (Drowsy) (Confidence: 595.59%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1014).jpg → Yawning (Non-Drowsy) (Confidence: 629.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1015).jpg → Yawning (Drowsy) (Confidence: 657.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1016).jpg → Yawning (Non-Drowsy) (Confidence: 469.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1017).jpg → Yawning (Drowsy) (Confidence: 656.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1018).jpg → Yawning (Non-Drowsy) (Confidence: 528.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1019).jpg → Yawning (Drowsy) (Confidence: 637.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (102).jpg → Happy (Non-Drowsy) (Confidence: 359.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1020).jpg → Yawning (Drowsy) (Confidence: 510.09%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1021).jpg → Yawning (Drowsy) (Confidence: 640.13%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1022).jpg → Yawning (Drowsy) (Confidence: 843.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1023).jpg → Yawning (Non-Drowsy) (Confidence: 608.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1024).jpg → Yawning (Drowsy) (Confidence: 850.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1025).jpg → Yawning (Non-Drowsy) (Confidence: 397.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1026).jpg → Yawning (Non-Drowsy) (Confidence: 619.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1027).jpg → Yawning (Drowsy) (Confidence: 845.88%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1028).jpg → Yawning (Non-Drowsy) (Confidence: 412.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1029).jpg → Yawning (Non-Drowsy) (Confidence: 587.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (103).jpg → Happy (Non-Drowsy) (Confidence: 357.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1030).jpg → Yawning (Non-Drowsy) (Confidence: 423.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1031).jpg → Yawning (Drowsy) (Confidence: 867.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1032).jpg → Yawning (Non-Drowsy) (Confidence: 583.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1033).jpg → Yawning (Drowsy) (Confidence: 763.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1034).jpg → Yawning (Non-Drowsy) (Confidence: 588.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1035).jpg → Yawning (Drowsy) (Confidence: 901.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1036).jpg → Yawning (Drowsy) (Confidence: 567.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1037).jpg → Happy (Non-Drowsy) (Confidence: 347.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1038).jpg → Yawning (Drowsy) (Confidence: 866.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1039).jpg → Yawning (Drowsy) (Confidence: 609.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (104).jpg → Happy (Non-Drowsy) (Confidence: 355.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1040).jpg → Yawning (Non-Drowsy) (Confidence: 381.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1041).jpg → Happy (Non-Drowsy) (Confidence: 463.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1042).jpg → Yawning (Drowsy) (Confidence: 576.8%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1043).jpg → Happy (Non-Drowsy) (Confidence: 596.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1044).jpg → Yawning (Non-Drowsy) (Confidence: 373.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1045).jpg → Yawning (Non-Drowsy) (Confidence: 611.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1046).jpg → Happy (Non-Drowsy) (Confidence: 558.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1047).jpg → Yawning (Non-Drowsy) (Confidence: 374.84%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1048).jpg → Happy (Non-Drowsy) (Confidence: 635.09%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1049).jpg → Happy (Non-Drowsy) (Confidence: 428.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (105).jpg → Happy (Non-Drowsy) (Confidence: 345.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1050).jpg → Happy (Non-Drowsy) (Confidence: 406.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1051).jpg → Yawning (Non-Drowsy) (Confidence: 397.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1052).jpg → Yawning (Drowsy) (Confidence: 411.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1053).jpg → Yawning (Non-Drowsy) (Confidence: 401.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1054).jpg → Yawning (Non-Drowsy) (Confidence: 410.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1055).jpg → Yawning (Drowsy) (Confidence: 800.96%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# ✅ Drowsy (1056).jpg → Yawning (Drowsy) (Confidence: 787.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1057).jpg → Yawning (Drowsy) (Confidence: 753.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1058).jpg → Yawning (Drowsy) (Confidence: 803.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1059).jpg → Yawning (Drowsy) (Confidence: 833.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (106).jpg → Happy (Non-Drowsy) (Confidence: 358.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1060).jpg → Yawning (Drowsy) (Confidence: 839.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1061).jpg → Happy (Non-Drowsy) (Confidence: 465.68%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1062).jpg → Yawning (Drowsy) (Confidence: 851.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1063).jpg → Happy (Non-Drowsy) (Confidence: 494.06%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1064).jpg → Yawning (Drowsy) (Confidence: 805.75%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1065).jpg → Yawning (Drowsy) (Confidence: 665.86%)
# 🚫 No face detected in Drowsy (1066).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1067).jpg → Yawning (Drowsy) (Confidence: 653.34%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1068).jpg → Yawning (Drowsy) (Confidence: 485.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1069).jpg → Happy (Non-Drowsy) (Confidence: 379.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (107).jpg → Happy (Non-Drowsy) (Confidence: 357.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Drowsy (1070).jpg → Happy (Non-Drowsy) (Confidence: 528.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1071).jpg → Happy (Non-Drowsy) (Confidence: 328.67%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1072).jpg → Happy (Non-Drowsy) (Confidence: 462.84%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1073).jpg → Happy (Non-Drowsy) (Confidence: 359.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1074).jpg → Happy (Non-Drowsy) (Confidence: 339.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1075).jpg → Happy (Non-Drowsy) (Confidence: 352.9%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1076).jpg → Happy (Non-Drowsy) (Confidence: 347.09%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1077).jpg → Happy (Non-Drowsy) (Confidence: 383.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1078).jpg → Happy (Non-Drowsy) (Confidence: 357.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1079).jpg → Happy (Non-Drowsy) (Confidence: 337.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# ✅ Drowsy (108).jpg → Happy (Non-Drowsy) (Confidence: 353.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1080).jpg → Happy (Non-Drowsy) (Confidence: 321.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1081).jpg → Happy (Non-Drowsy) (Confidence: 344.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1082).jpg → Happy (Non-Drowsy) (Confidence: 348.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1083).jpg → Happy (Non-Drowsy) (Confidence: 358.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1084).jpg → Happy (Non-Drowsy) (Confidence: 346.77%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1085).jpg → Happy (Non-Drowsy) (Confidence: 372.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1086).jpg → Happy (Non-Drowsy) (Confidence: 323.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1087).jpg → Happy (Non-Drowsy) (Confidence: 412.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1088).jpg → Happy (Non-Drowsy) (Confidence: 347.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1089).jpg → Happy (Non-Drowsy) (Confidence: 472.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (109).jpg → Happy (Non-Drowsy) (Confidence: 357.77%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1090).jpg → Happy (Non-Drowsy) (Confidence: 473.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1091).jpg → Happy (Non-Drowsy) (Confidence: 329.87%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Drowsy (1092).jpg → Happy (Non-Drowsy) (Confidence: 337.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1093).jpg → Happy (Non-Drowsy) (Confidence: 455.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1094).jpg → Happy (Non-Drowsy) (Confidence: 341.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1095).jpg → Happy (Non-Drowsy) (Confidence: 496.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1096).jpg → Happy (Non-Drowsy) (Confidence: 311.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1097).jpg → Happy (Non-Drowsy) (Confidence: 492.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1098).jpg → Happy (Non-Drowsy) (Confidence: 312.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1099).jpg → Happy (Non-Drowsy) (Confidence: 328.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (11).png → Yawning (Drowsy) (Confidence: 539.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (110).jpg → Happy (Non-Drowsy) (Confidence: 359.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1100).jpg → Happy (Non-Drowsy) (Confidence: 345.73%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# ✅ Drowsy (1101).jpg → Happy (Non-Drowsy) (Confidence: 288.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1102).jpg → Happy (Non-Drowsy) (Confidence: 306.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1103).jpg → Yawning (Drowsy) (Confidence: 723.22%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1104).jpg → Yawning (Drowsy) (Confidence: 837.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1105).jpg → Yawning (Drowsy) (Confidence: 780.84%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1106).jpg → Yawning (Drowsy) (Confidence: 485.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1107).jpg → Yawning (Drowsy) (Confidence: 590.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1108).jpg → Yawning (Drowsy) (Confidence: 589.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1109).jpg → Yawning (Drowsy) (Confidence: 615.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (111).jpg → Happy (Non-Drowsy) (Confidence: 344.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1110).jpg → Yawning (Drowsy) (Confidence: 766.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1111).jpg → Yawning (Drowsy) (Confidence: 475.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1112).jpg → Yawning (Drowsy) (Confidence: 894.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1113).jpg → Yawning (Drowsy) (Confidence: 852.16%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1114).jpg → Yawning (Drowsy) (Confidence: 494.69%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1115).jpg → Yawning (Drowsy) (Confidence: 550.73%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1116).jpg → Yawning (Drowsy) (Confidence: 550.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1117).jpg → Happy (Non-Drowsy) (Confidence: 395.97%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1118).jpg → Yawning (Drowsy) (Confidence: 442.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1119).jpg → Yawning (Drowsy) (Confidence: 561.06%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (112).jpg → Happy (Non-Drowsy) (Confidence: 356.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1120).jpg → Yawning (Drowsy) (Confidence: 592.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1121).jpg → Yawning (Drowsy) (Confidence: 599.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1122).jpg → Yawning (Drowsy) (Confidence: 488.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# ✅ Drowsy (1123).jpg → Yawning (Drowsy) (Confidence: 496.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Drowsy (1124).jpg → Yawning (Drowsy) (Confidence: 542.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1125).jpg → Yawning (Drowsy) (Confidence: 637.17%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1126).jpg → Happy (Non-Drowsy) (Confidence: 362.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1127).jpg → Yawning (Drowsy) (Confidence: 661.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1128).jpg → Happy (Non-Drowsy) (Confidence: 476.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1129).jpg → Happy (Non-Drowsy) (Confidence: 347.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (113).jpg → Happy (Non-Drowsy) (Confidence: 365.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1130).jpg → Happy (Non-Drowsy) (Confidence: 483.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1131).jpg → Happy (Non-Drowsy) (Confidence: 327.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1132).jpg → Happy (Non-Drowsy) (Confidence: 349.96%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1133).jpg → Happy (Non-Drowsy) (Confidence: 509.35%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1134).jpg → Happy (Non-Drowsy) (Confidence: 356.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1135).jpg → Happy (Non-Drowsy) (Confidence: 576.55%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1136).jpg → Happy (Non-Drowsy) (Confidence: 547.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1137).jpg → Happy (Non-Drowsy) (Confidence: 572.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1138).jpg → Happy (Non-Drowsy) (Confidence: 564.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1139).jpg → Yawning (Drowsy) (Confidence: 785.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (114).jpg → Happy (Non-Drowsy) (Confidence: 371.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1140).jpg → Yawning (Non-Drowsy) (Confidence: 822.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1141).jpg → Yawning (Non-Drowsy) (Confidence: 819.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1142).jpg → Yawning (Drowsy) (Confidence: 837.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1143).jpg → Yawning (Drowsy) (Confidence: 828.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1144).jpg → Yawning (Drowsy) (Confidence: 803.13%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1145).jpg → Yawning (Drowsy) (Confidence: 808.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (1146).jpg → Yawning (Drowsy) (Confidence: 857.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1147).jpg → Yawning (Drowsy) (Confidence: 841.88%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1148).jpg → Yawning (Drowsy) (Confidence: 893.74%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1149).jpg → Yawning (Drowsy) (Confidence: 858.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (115).jpg → Happy (Non-Drowsy) (Confidence: 357.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1150).jpg → Yawning (Non-Drowsy) (Confidence: 860.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1151).jpg → Happy (Non-Drowsy) (Confidence: 471.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1152).jpg → Happy (Non-Drowsy) (Confidence: 444.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1153).jpg → Happy (Non-Drowsy) (Confidence: 430.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1154).jpg → Happy (Non-Drowsy) (Confidence: 518.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1155).jpg → Happy (Non-Drowsy) (Confidence: 507.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1156).jpg → Happy (Non-Drowsy) (Confidence: 527.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1157).jpg → Yawning (Non-Drowsy) (Confidence: 812.87%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1158).jpg → Yawning (Non-Drowsy) (Confidence: 886.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1159).jpg → Yawning (Non-Drowsy) (Confidence: 885.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (116).jpg → Happy (Non-Drowsy) (Confidence: 375.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1160).jpg → Yawning (Drowsy) (Confidence: 810.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1161).jpg → Happy (Non-Drowsy) (Confidence: 334.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1162).jpg → Yawning (Non-Drowsy) (Confidence: 816.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1163).jpg → Happy (Non-Drowsy) (Confidence: 333.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1164).jpg → Yawning (Non-Drowsy) (Confidence: 820.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1165).jpg → Happy (Non-Drowsy) (Confidence: 423.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1166).jpg → Happy (Non-Drowsy) (Confidence: 431.08%)
# 🚫 No face detected in Drowsy (1167).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (1168).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1169).jpg → Happy (Non-Drowsy) (Confidence: 394.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (117).jpg → Happy (Non-Drowsy) (Confidence: 372.81%)
# 🚫 No face detected in Drowsy (1170).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1171).jpg → Yawning (Drowsy) (Confidence: 393.51%)
# 🚫 No face detected in Drowsy (1172).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (1173).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1174).jpg → Yawning (Drowsy) (Confidence: 431.89%)
# 🚫 No face detected in Drowsy (1175).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1176).jpg → Happy (Non-Drowsy) (Confidence: 423.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1177).jpg → Happy (Non-Drowsy) (Confidence: 398.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1178).jpg → Happy (Non-Drowsy) (Confidence: 405.34%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1179).jpg → Happy (Non-Drowsy) (Confidence: 417.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (118).jpg → Happy (Non-Drowsy) (Confidence: 366.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1180).jpg → Happy (Non-Drowsy) (Confidence: 420.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1181).jpg → Happy (Non-Drowsy) (Confidence: 392.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1182).jpg → Happy (Non-Drowsy) (Confidence: 440.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1183).jpg → Yawning (Non-Drowsy) (Confidence: 734.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1184).jpg → Yawning (Non-Drowsy) (Confidence: 681.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1185).jpg → Yawning (Non-Drowsy) (Confidence: 719.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1186).jpg → Yawning (Non-Drowsy) (Confidence: 870.04%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1187).jpg → Yawning (Non-Drowsy) (Confidence: 848.9%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1188).jpg → Yawning (Non-Drowsy) (Confidence: 690.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1189).jpg → Happy (Non-Drowsy) (Confidence: 530.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (119).jpg → Happy (Non-Drowsy) (Confidence: 370.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1190).jpg → Happy (Non-Drowsy) (Confidence: 481.24%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1191).jpg → Happy (Non-Drowsy) (Confidence: 490.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1192).jpg → Happy (Non-Drowsy) (Confidence: 602.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1193).jpg → Happy (Non-Drowsy) (Confidence: 540.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# ✅ Drowsy (1194).jpg → Yawning (Non-Drowsy) (Confidence: 384.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (1195).jpg → Happy (Non-Drowsy) (Confidence: 454.85%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1196).jpg → Happy (Non-Drowsy) (Confidence: 532.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1197).jpg → Yawning (Non-Drowsy) (Confidence: 380.78%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1198).jpg → Happy (Non-Drowsy) (Confidence: 540.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1199).jpg → Yawning (Non-Drowsy) (Confidence: 385.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (12).png → Yawning (Drowsy) (Confidence: 518.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (120).jpg → Happy (Non-Drowsy) (Confidence: 364.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1200).jpg → Happy (Non-Drowsy) (Confidence: 460.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1201).jpg → Happy (Non-Drowsy) (Confidence: 563.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1202).jpg → Yawning (Non-Drowsy) (Confidence: 433.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1203).jpg → Happy (Non-Drowsy) (Confidence: 558.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1204).jpg → Yawning (Non-Drowsy) (Confidence: 400.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1205).jpg → Happy (Non-Drowsy) (Confidence: 516.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1206).jpg → Yawning (Drowsy) (Confidence: 423.55%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1207).jpg → Yawning (Drowsy) (Confidence: 396.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1208).jpg → Happy (Non-Drowsy) (Confidence: 365.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1209).jpg → Happy (Non-Drowsy) (Confidence: 388.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (121).jpg → Happy (Non-Drowsy) (Confidence: 365.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1210).jpg → Yawning (Drowsy) (Confidence: 385.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1211).jpg → Yawning (Non-Drowsy) (Confidence: 388.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1212).jpg → Happy (Non-Drowsy) (Confidence: 358.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1213).jpg → Yawning (Drowsy) (Confidence: 431.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# ✅ Drowsy (1214).jpg → Yawning (Drowsy) (Confidence: 431.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1215).jpg → Yawning (Non-Drowsy) (Confidence: 557.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1216).jpg → Yawning (Non-Drowsy) (Confidence: 494.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1217).jpg → Happy (Non-Drowsy) (Confidence: 448.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1218).jpg → Happy (Non-Drowsy) (Confidence: 443.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1219).jpg → Yawning (Non-Drowsy) (Confidence: 468.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (122).jpg → Happy (Non-Drowsy) (Confidence: 379.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1220).jpg → Happy (Non-Drowsy) (Confidence: 448.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1221).jpg → Yawning (Drowsy) (Confidence: 429.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1222).jpg → Happy (Non-Drowsy) (Confidence: 474.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1223).jpg → Yawning (Drowsy) (Confidence: 326.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1224).jpg → Happy (Non-Drowsy) (Confidence: 401.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1225).jpg → Happy (Non-Drowsy) (Confidence: 480.06%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1226).jpg → Yawning (Drowsy) (Confidence: 405.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1227).jpg → Happy (Non-Drowsy) (Confidence: 481.55%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1228).jpg → Yawning (Drowsy) (Confidence: 394.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1229).jpg → Happy (Non-Drowsy) (Confidence: 471.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (123).jpg → Happy (Non-Drowsy) (Confidence: 372.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1230).jpg → Happy (Non-Drowsy) (Confidence: 418.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1231).jpg → Happy (Non-Drowsy) (Confidence: 411.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1232).jpg → Happy (Non-Drowsy) (Confidence: 446.17%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1233).jpg → Happy (Non-Drowsy) (Confidence: 450.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ✅ Drowsy (1234).jpg → Happy (Non-Drowsy) (Confidence: 478.67%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1235).jpg → Yawning (Drowsy) (Confidence: 473.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1236).jpg → Yawning (Drowsy) (Confidence: 419.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1237).jpg → Yawning (Drowsy) (Confidence: 450.74%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1238).jpg → Happy (Non-Drowsy) (Confidence: 457.6%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1239).jpg → Yawning (Non-Drowsy) (Confidence: 453.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (124).jpg → Happy (Non-Drowsy) (Confidence: 387.04%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1240).jpg → Yawning (Non-Drowsy) (Confidence: 453.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1241).jpg → Happy (Non-Drowsy) (Confidence: 461.59%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1242).jpg → Yawning (Non-Drowsy) (Confidence: 475.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1243).jpg → Yawning (Drowsy) (Confidence: 401.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1244).jpg → Happy (Non-Drowsy) (Confidence: 473.35%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1245).jpg → Yawning (Drowsy) (Confidence: 600.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1246).jpg → Happy (Non-Drowsy) (Confidence: 462.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1247).jpg → Yawning (Drowsy) (Confidence: 502.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1248).jpg → Happy (Non-Drowsy) (Confidence: 402.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1249).jpg → Yawning (Drowsy) (Confidence: 445.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (125).jpg → Happy (Non-Drowsy) (Confidence: 400.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1250).jpg → Happy (Non-Drowsy) (Confidence: 571.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1251).jpg → Yawning (Drowsy) (Confidence: 452.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1252).jpg → Yawning (Drowsy) (Confidence: 470.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1253).jpg → Happy (Non-Drowsy) (Confidence: 575.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1254).jpg → Yawning (Drowsy) (Confidence: 442.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1255).jpg → Yawning (Drowsy) (Confidence: 457.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1256).jpg → Yawning (Drowsy) (Confidence: 562.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1257).jpg → Yawning (Drowsy) (Confidence: 601.69%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1258).jpg → Yawning (Drowsy) (Confidence: 627.68%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1259).jpg → Yawning (Drowsy) (Confidence: 636.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (126).jpg → Happy (Non-Drowsy) (Confidence: 402.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1260).jpg → Yawning (Drowsy) (Confidence: 627.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1261).jpg → Yawning (Drowsy) (Confidence: 659.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1262).jpg → Yawning (Drowsy) (Confidence: 608.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1263).jpg → Happy (Non-Drowsy) (Confidence: 424.75%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1264).jpg → Yawning (Non-Drowsy) (Confidence: 392.5%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1265).jpg → Yawning (Non-Drowsy) (Confidence: 415.6%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1266).jpg → Happy (Non-Drowsy) (Confidence: 417.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1267).jpg → Yawning (Non-Drowsy) (Confidence: 426.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1268).jpg → Yawning (Non-Drowsy) (Confidence: 877.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1269).jpg → Yawning (Non-Drowsy) (Confidence: 812.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (127).jpg → Happy (Non-Drowsy) (Confidence: 398.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1270).jpg → Happy (Non-Drowsy) (Confidence: 570.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1271).jpg → Happy (Non-Drowsy) (Confidence: 570.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1272).jpg → Yawning (Non-Drowsy) (Confidence: 779.49%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1273).jpg → Happy (Non-Drowsy) (Confidence: 564.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1274).jpg → Yawning (Non-Drowsy) (Confidence: 778.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1275).jpg → Happy (Non-Drowsy) (Confidence: 569.28%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1276).jpg → Yawning (Non-Drowsy) (Confidence: 754.13%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1277).jpg → Yawning (Drowsy) (Confidence: 781.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1278).jpg → Happy (Non-Drowsy) (Confidence: 596.5%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1279).jpg → Yawning (Non-Drowsy) (Confidence: 760.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (128).jpg → Happy (Non-Drowsy) (Confidence: 397.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1280).jpg → Yawning (Non-Drowsy) (Confidence: 793.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1281).jpg → Happy (Non-Drowsy) (Confidence: 603.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1282).jpg → Yawning (Non-Drowsy) (Confidence: 864.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1283).jpg → Yawning (Non-Drowsy) (Confidence: 925.96%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (1284).jpg → Yawning (Non-Drowsy) (Confidence: 886.85%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (1285).jpg → Yawning (Non-Drowsy) (Confidence: 869.6%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1286).jpg → Happy (Non-Drowsy) (Confidence: 480.55%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1287).jpg → Happy (Non-Drowsy) (Confidence: 457.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1288).jpg → Yawning (Non-Drowsy) (Confidence: 520.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1289).jpg → Yawning (Drowsy) (Confidence: 527.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (129).jpg → Happy (Non-Drowsy) (Confidence: 381.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1290).jpg → Yawning (Drowsy) (Confidence: 475.78%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1291).jpg → Yawning (Drowsy) (Confidence: 481.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (1292).jpg → Happy (Non-Drowsy) (Confidence: 371.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1293).jpg → Happy (Non-Drowsy) (Confidence: 391.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1294).jpg → Happy (Non-Drowsy) (Confidence: 322.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1295).jpg → Happy (Non-Drowsy) (Confidence: 412.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1296).jpg → Yawning (Non-Drowsy) (Confidence: 350.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1297).jpg → Yawning (Non-Drowsy) (Confidence: 374.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1298).jpg → Happy (Non-Drowsy) (Confidence: 359.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1299).jpg → Happy (Non-Drowsy) (Confidence: 442.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (13).png → Yawning (Drowsy) (Confidence: 424.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (130).jpg → Happy (Non-Drowsy) (Confidence: 390.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1300).jpg → Happy (Non-Drowsy) (Confidence: 464.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1301).jpg → Yawning (Non-Drowsy) (Confidence: 340.35%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1302).jpg → Happy (Non-Drowsy) (Confidence: 478.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1303).jpg → Happy (Non-Drowsy) (Confidence: 330.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1304).jpg → Yawning (Non-Drowsy) (Confidence: 467.97%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1305).jpg → Happy (Non-Drowsy) (Confidence: 517.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1306).jpg → Happy (Non-Drowsy) (Confidence: 315.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# ✅ Drowsy (1307).jpg → Happy (Non-Drowsy) (Confidence: 603.17%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1308).jpg → Happy (Non-Drowsy) (Confidence: 574.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1309).jpg → Happy (Non-Drowsy) (Confidence: 590.52%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (131).jpg → Happy (Non-Drowsy) (Confidence: 410.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1310).jpg → Happy (Non-Drowsy) (Confidence: 523.97%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1311).jpg → Yawning (Drowsy) (Confidence: 487.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1312).jpg → Yawning (Non-Drowsy) (Confidence: 490.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1313).jpg → Yawning (Non-Drowsy) (Confidence: 428.22%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1314).jpg → Happy (Non-Drowsy) (Confidence: 417.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1315).jpg → Happy (Non-Drowsy) (Confidence: 389.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (1316).jpg → Happy (Non-Drowsy) (Confidence: 393.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1317).jpg → Yawning (Non-Drowsy) (Confidence: 391.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1318).jpg → Yawning (Non-Drowsy) (Confidence: 375.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1319).jpg → Happy (Non-Drowsy) (Confidence: 493.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (132).jpg → Happy (Non-Drowsy) (Confidence: 406.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1320).jpg → Yawning (Drowsy) (Confidence: 482.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1321).jpg → Happy (Non-Drowsy) (Confidence: 544.68%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1322).jpg → Yawning (Non-Drowsy) (Confidence: 403.6%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1323).jpg → Happy (Non-Drowsy) (Confidence: 520.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1324).jpg → Happy (Non-Drowsy) (Confidence: 393.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1325).jpg → Happy (Non-Drowsy) (Confidence: 381.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1326).jpg → Happy (Non-Drowsy) (Confidence: 490.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1327).jpg → Happy (Non-Drowsy) (Confidence: 399.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1328).jpg → Yawning (Non-Drowsy) (Confidence: 487.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1329).jpg → Happy (Non-Drowsy) (Confidence: 383.09%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (133).jpg → Happy (Non-Drowsy) (Confidence: 414.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (1330).jpg → Yawning (Non-Drowsy) (Confidence: 408.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (1331).jpg → Happy (Non-Drowsy) (Confidence: 563.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (1332).jpg → Happy (Non-Drowsy) (Confidence: 413.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1333).jpg → Happy (Non-Drowsy) (Confidence: 430.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1334).jpg → Yawning (Drowsy) (Confidence: 564.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1335).jpg → Yawning (Drowsy) (Confidence: 553.96%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1336).jpg → Yawning (Drowsy) (Confidence: 507.77%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1337).jpg → Yawning (Drowsy) (Confidence: 433.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1338).jpg → Yawning (Drowsy) (Confidence: 575.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1339).jpg → Yawning (Drowsy) (Confidence: 576.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (134).jpg → Happy (Non-Drowsy) (Confidence: 398.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1340).jpg → Yawning (Non-Drowsy) (Confidence: 600.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1341).jpg → Yawning (Drowsy) (Confidence: 566.65%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1342).jpg → Yawning (Drowsy) (Confidence: 516.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1343).jpg → Yawning (Drowsy) (Confidence: 502.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1344).jpg → Yawning (Non-Drowsy) (Confidence: 485.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1345).jpg → Yawning (Drowsy) (Confidence: 442.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1346).jpg → Happy (Non-Drowsy) (Confidence: 573.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1347).jpg → Happy (Non-Drowsy) (Confidence: 572.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1348).jpg → Yawning (Drowsy) (Confidence: 516.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1349).jpg → Happy (Non-Drowsy) (Confidence: 581.23%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (135).jpg → Happy (Non-Drowsy) (Confidence: 383.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (1350).jpg → Happy (Non-Drowsy) (Confidence: 296.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1351).jpg → Yawning (Non-Drowsy) (Confidence: 333.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (1352).jpg → Happy (Non-Drowsy) (Confidence: 581.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (1353).jpg → Happy (Non-Drowsy) (Confidence: 534.82%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (1354).jpg → Happy (Non-Drowsy) (Confidence: 356.22%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# ✅ Drowsy (1355).jpg → Happy (Non-Drowsy) (Confidence: 577.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step✅ Drowsy (2632).jpg → Happy (Non-Drowsy) (Confidence: 253.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2633).jpg → Happy (Non-Drowsy) (Confidence: 228.58%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (2634).jpg → Yawning (Non-Drowsy) (Confidence: 584.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (2635).jpg → Yawning (Non-Drowsy) (Confidence: 350.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2636).jpg → Yawning (Drowsy) (Confidence: 470.06%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2637).jpg → Yawning (Drowsy) (Confidence: 429.09%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (2638).jpg → Yawning (Drowsy) (Confidence: 453.2%)
# 🚫 No face detected in Drowsy (2639).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2640).jpg → Yawning (Non-Drowsy) (Confidence: 268.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2641).jpg → Neutral (Non-Drowsy) (Confidence: 195.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (2642).jpg → Yawning (Drowsy) (Confidence: 553.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2643).jpg → Yawning (Non-Drowsy) (Confidence: 405.49%)
# 🚫 No face detected in Drowsy (2644).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2645).jpg → Yawning (Drowsy) (Confidence: 372.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (2646).jpg → Yawning (Non-Drowsy) (Confidence: 277.22%)
# 🚫 No face detected in Drowsy (2647).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2648).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2649).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2650).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2651).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (2652).jpg → Happy (Non-Drowsy) (Confidence: 395.68%)
# 🚫 No face detected in Drowsy (2653).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2654).jpg → Yawning (Drowsy) (Confidence: 376.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2655).jpg → Yawning (Non-Drowsy) (Confidence: 533.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2656).jpg → Yawning (Drowsy) (Confidence: 420.17%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (2657).jpg → Yawning (Drowsy) (Confidence: 537.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (2658).jpg → Yawning (Drowsy) (Confidence: 602.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Drowsy (2659).jpg → Yawning (Drowsy) (Confidence: 641.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (2660).jpg → Yawning (Drowsy) (Confidence: 474.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2661).jpg → Yawning (Drowsy) (Confidence: 586.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2662).jpg → Yawning (Drowsy) (Confidence: 418.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2663).jpg → Yawning (Drowsy) (Confidence: 286.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# ✅ Drowsy (2664).jpg → Yawning (Non-Drowsy) (Confidence: 433.76%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (2665).jpg → Yawning (Non-Drowsy) (Confidence: 449.73%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2666).jpg → Yawning (Non-Drowsy) (Confidence: 263.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2667).jpg → Yawning (Non-Drowsy) (Confidence: 410.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (2668).jpg → Yawning (Non-Drowsy) (Confidence: 294.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2669).jpg → Yawning (Drowsy) (Confidence: 329.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2670).jpg → Yawning (Drowsy) (Confidence: 311.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (2671).jpg → Yawning (Drowsy) (Confidence: 322.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2672).jpg → Yawning (Drowsy) (Confidence: 522.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2673).jpg → Yawning (Drowsy) (Confidence: 300.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (2674).jpg → Yawning (Drowsy) (Confidence: 336.06%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2675).jpg → Yawning (Drowsy) (Confidence: 341.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2676).jpg → Yawning (Drowsy) (Confidence: 482.51%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2677).jpg → Yawning (Drowsy) (Confidence: 473.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2678).jpg → Yawning (Drowsy) (Confidence: 380.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2679).jpg → Yawning (Drowsy) (Confidence: 438.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2680).jpg → Yawning (Drowsy) (Confidence: 408.7%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2681).jpg → Yawning (Drowsy) (Confidence: 529.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2682).jpg → Yawning (Drowsy) (Confidence: 429.72%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2683).jpg → Yawning (Drowsy) (Confidence: 410.67%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2684).jpg → Yawning (Drowsy) (Confidence: 470.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2685).jpg → Yawning (Drowsy) (Confidence: 400.2%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2686).jpg → Yawning (Drowsy) (Confidence: 478.59%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2687).jpg → Yawning (Drowsy) (Confidence: 406.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2688).jpg → Neutral (Drowsy) (Confidence: 368.89%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2689).jpg → Yawning (Drowsy) (Confidence: 309.56%)
# 🚫 No face detected in Drowsy (2690).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2691).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2692).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2693).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2694).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2695).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2696).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2697).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2698).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2699).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (27).png → Eyes Closed (Drowsy) (Confidence: 274.39%)
# 🚫 No face detected in Drowsy (2700).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2701).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2702).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2703).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2704).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2705).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2706).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2707).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (2708).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2709).jpg → Yawning (Drowsy) (Confidence: 308.27%)
# 🚫 No face detected in Drowsy (2710).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2711).jpg → Yawning (Drowsy) (Confidence: 350.97%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2712).jpg → Yawning (Drowsy) (Confidence: 487.84%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2713).jpg → Yawning (Drowsy) (Confidence: 507.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2714).jpg → Yawning (Drowsy) (Confidence: 414.88%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2715).jpg → Yawning (Drowsy) (Confidence: 388.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2716).jpg → Yawning (Drowsy) (Confidence: 503.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (2717).jpg → Yawning (Drowsy) (Confidence: 472.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (2718).jpg → Yawning (Drowsy) (Confidence: 454.44%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (2719).jpg → Yawning (Drowsy) (Confidence: 386.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2720).jpg → Yawning (Drowsy) (Confidence: 337.8%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2721).jpg → Yawning (Drowsy) (Confidence: 518.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (2722).jpg → Yawning (Drowsy) (Confidence: 373.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (2723).jpg → Yawning (Drowsy) (Confidence: 455.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3120).jpg → Yawning (Drowsy) (Confidence: 419.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3121).jpg → Yawning (Drowsy) (Confidence: 431.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3122).jpg → Yawning (Drowsy) (Confidence: 343.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3123).jpg → Yawning (Drowsy) (Confidence: 342.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3124).jpg → Yawning (Drowsy) (Confidence: 441.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3125).jpg → Yawning (Drowsy) (Confidence: 295.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3126).jpg → Yawning (Drowsy) (Confidence: 409.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3127).jpg → Yawning (Drowsy) (Confidence: 480.77%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3128).jpg → Yawning (Drowsy) (Confidence: 396.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3129).jpg → Yawning (Drowsy) (Confidence: 384.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3130).jpg → Yawning (Drowsy) (Confidence: 382.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3131).jpg → Yawning (Drowsy) (Confidence: 286.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3132).jpg → Yawning (Drowsy) (Confidence: 373.32%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3133).jpg → Yawning (Drowsy) (Confidence: 321.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3134).jpg → Yawning (Drowsy) (Confidence: 334.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3135).jpg → Yawning (Drowsy) (Confidence: 337.78%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3136).jpg → Yawning (Drowsy) (Confidence: 341.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# ✅ Drowsy (3137).jpg → Yawning (Drowsy) (Confidence: 298.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3138).jpg → Yawning (Drowsy) (Confidence: 331.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3139).jpg → Yawning (Drowsy) (Confidence: 303.04%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3140).jpg → Yawning (Drowsy) (Confidence: 385.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3141).jpg → Yawning (Drowsy) (Confidence: 271.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3142).jpg → Yawning (Drowsy) (Confidence: 364.25%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3143).jpg → Yawning (Drowsy) (Confidence: 411.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3144).jpg → Yawning (Drowsy) (Confidence: 338.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3145).jpg → Yawning (Drowsy) (Confidence: 429.73%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3146).jpg → Yawning (Drowsy) (Confidence: 329.91%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3147).jpg → Yawning (Drowsy) (Confidence: 211.13%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3148).jpg → Yawning (Drowsy) (Confidence: 415.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3149).jpg → Yawning (Drowsy) (Confidence: 421.45%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3150).jpg → Yawning (Drowsy) (Confidence: 334.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3151).jpg → Yawning (Drowsy) (Confidence: 299.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3152).jpg → Yawning (Drowsy) (Confidence: 333.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3153).jpg → Yawning (Drowsy) (Confidence: 431.85%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3154).jpg → Yawning (Drowsy) (Confidence: 464.55%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3155).jpg → Yawning (Drowsy) (Confidence: 287.67%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3156).jpg → Yawning (Drowsy) (Confidence: 355.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3157).jpg → Yawning (Drowsy) (Confidence: 386.9%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3158).jpg → Yawning (Drowsy) (Confidence: 365.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3159).jpg → Yawning (Drowsy) (Confidence: 317.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3160).jpg → Yawning (Drowsy) (Confidence: 351.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3161).jpg → Yawning (Drowsy) (Confidence: 323.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3162).jpg → Yawning (Drowsy) (Confidence: 388.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3163).jpg → Yawning (Drowsy) (Confidence: 260.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3164).jpg → Yawning (Drowsy) (Confidence: 370.75%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3165).jpg → Yawning (Drowsy) (Confidence: 368.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3166).jpg → Yawning (Drowsy) (Confidence: 374.63%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3167).jpg → Yawning (Drowsy) (Confidence: 384.9%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3168).jpg → Yawning (Drowsy) (Confidence: 322.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3169).jpg → Yawning (Drowsy) (Confidence: 277.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# ✅ Drowsy (3170).jpg → Yawning (Drowsy) (Confidence: 275.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3171).jpg → Yawning (Drowsy) (Confidence: 284.74%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3172).jpg → Yawning (Drowsy) (Confidence: 287.12%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3173).jpg → Yawning (Drowsy) (Confidence: 303.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (3174).jpg → Yawning (Drowsy) (Confidence: 323.74%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Drowsy (3175).jpg → Yawning (Drowsy) (Confidence: 174.81%)
# 🚫 No face detected in Drowsy (3176).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3177).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3178).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3179).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3180).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3181).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3182).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3183).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3184).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3185).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3186).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3187).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3188).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3189).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3190).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3191).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3192).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3193).jpg. Marking as uncertain.
# 🚫 No face detected in Drowsy (3194).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3195).jpg → Happy (Drowsy) (Confidence: 169.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3196).jpg → Yawning (Drowsy) (Confidence: 291.5%)
# 🚫 No face detected in Drowsy (3197).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3198).jpg → Yawning (Drowsy) (Confidence: 281.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3199).jpg → Yawning (Drowsy) (Confidence: 252.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (32).png → Eyes Closed (Drowsy) (Confidence: 316.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3200).jpg → Yawning (Drowsy) (Confidence: 211.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3201).jpg → Yawning (Drowsy) (Confidence: 246.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3202).jpg → Yawning (Drowsy) (Confidence: 324.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3203).jpg → Yawning (Drowsy) (Confidence: 351.28%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ✅ Drowsy (3204).jpg → Yawning (Drowsy) (Confidence: 297.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3205).jpg → Yawning (Drowsy) (Confidence: 299.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3206).jpg → Neutral (Drowsy) (Confidence: 165.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3207).jpg → Yawning (Drowsy) (Confidence: 384.9%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3208).jpg → Yawning (Drowsy) (Confidence: 280.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3209).jpg → Yawning (Drowsy) (Confidence: 243.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3210).jpg → Neutral (Drowsy) (Confidence: 337.37%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3211).jpg → Yawning (Drowsy) (Confidence: 358.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3212).jpg → Yawning (Drowsy) (Confidence: 267.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3213).jpg → Yawning (Drowsy) (Confidence: 299.0%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3214).jpg → Yawning (Drowsy) (Confidence: 320.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3215).jpg → Yawning (Drowsy) (Confidence: 350.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3216).jpg → Yawning (Drowsy) (Confidence: 262.97%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3217).jpg → Yawning (Drowsy) (Confidence: 350.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3218).jpg → Yawning (Drowsy) (Confidence: 339.47%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3219).jpg → Yawning (Drowsy) (Confidence: 342.02%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3220).jpg → Yawning (Drowsy) (Confidence: 370.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3221).jpg → Yawning (Drowsy) (Confidence: 352.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3222).jpg → Neutral (Drowsy) (Confidence: 217.73%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3223).jpg → Yawning (Drowsy) (Confidence: 336.48%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3224).jpg → Yawning (Drowsy) (Confidence: 360.18%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3225).jpg → Yawning (Drowsy) (Confidence: 322.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ Drowsy (3226).jpg → Yawning (Drowsy) (Confidence: 293.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3227).jpg → Yawning (Drowsy) (Confidence: 284.81%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3228).jpg → Yawning (Drowsy) (Confidence: 365.5%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3229).jpg → Yawning (Drowsy) (Confidence: 355.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Drowsy (3230).jpg → Yawning (Drowsy) (Confidence: 247.42%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3231).jpg → Yawning (Drowsy) (Confidence: 338.83%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3232).jpg → Yawning (Drowsy) (Confidence: 392.03%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3268).jpg → Yawning (Drowsy) (Confidence: 314.62%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3269).jpg → Yawning (Drowsy) (Confidence: 270.11%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3270).jpg → Yawning (Drowsy) (Confidence: 322.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ✅ Drowsy (3271).jpg → Yawning (Drowsy) (Confidence: 343.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ✅ Drowsy (3272).jpg → Yawning (Drowsy) (Confidence: 248.31%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3273).jpg → Yawning (Drowsy) (Confidence: 307.34%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3274).jpg → Yawning (Drowsy) (Confidence: 223.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3275).jpg → Neutral (Drowsy) (Confidence: 305.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3276).jpg → Yawning (Drowsy) (Confidence: 238.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Drowsy (3277).jpg → Yawning (Drowsy) (Confidence: 342.27%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3278).jpg → Yawning (Drowsy) (Confidence: 323.42%)
# 🚫 No face detected in Drowsy (3279).jpg. Marking as uncertain.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3280).jpg → Yawning (Drowsy) (Confidence: 322.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3281).jpg → Yawning (Drowsy) (Confidence: 331.31%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ✅ Drowsy (3282).jpg → Yawning (Drowsy) (Confidence: 251.87%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3283).jpg → Yawning (Drowsy) (Confidence: 279.4%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3284).jpg → Yawning (Drowsy) (Confidence: 395.74%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3285).jpg → Yawning (Drowsy) (Confidence: 405.73%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3286).jpg → Yawning (Drowsy) (Confidence: 253.56%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3287).jpg → Yawning (Drowsy) (Confidence: 331.26%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3288).jpg → Yawning (Drowsy) (Confidence: 254.46%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3289).jpg → Yawning (Drowsy) (Confidence: 341.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3290).jpg → Yawning (Drowsy) (Confidence: 316.99%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# ✅ Drowsy (3291).jpg → Yawning (Drowsy) (Confidence: 371.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3292).jpg → Yawning (Drowsy) (Confidence: 353.88%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3293).jpg → Neutral (Drowsy) (Confidence: 325.01%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3294).jpg → Yawning (Drowsy) (Confidence: 298.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3295).jpg → Yawning (Drowsy) (Confidence: 317.54%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3296).jpg → Yawning (Drowsy) (Confidence: 291.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3297).jpg → Yawning (Drowsy) (Confidence: 266.74%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3298).jpg → Yawning (Drowsy) (Confidence: 324.1%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3299).jpg → Yawning (Drowsy) (Confidence: 369.38%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (33).png → Neutral (Non-Drowsy) (Confidence: 397.61%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3300).jpg → Yawning (Drowsy) (Confidence: 405.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3301).jpg → Yawning (Drowsy) (Confidence: 268.24%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3302).jpg → Yawning (Drowsy) (Confidence: 242.59%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3303).jpg → Yawning (Drowsy) (Confidence: 256.78%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3304).jpg → Yawning (Drowsy) (Confidence: 387.69%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3305).jpg → Yawning (Drowsy) (Confidence: 385.41%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# ✅ Drowsy (3306).jpg → Yawning (Drowsy) (Confidence: 370.68%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3307).jpg → Yawning (Drowsy) (Confidence: 271.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3308).jpg → Yawning (Drowsy) (Confidence: 368.92%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3309).jpg → Yawning (Drowsy) (Confidence: 330.05%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3310).jpg → Yawning (Drowsy) (Confidence: 260.94%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3311).jpg → Yawning (Drowsy) (Confidence: 328.66%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Drowsy (3312).jpg → Yawning (Drowsy) (Confidence: 267.39%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ✅ Drowsy (3313).jpg → Yawning (Drowsy) (Confidence: 307.08%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ✅ Drowsy (3314).jpg → Yawning (Drowsy) (Confidence: 244.33%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Drowsy (3315).jpg → Yawning (Drowsy) (Confidence: 345.87%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3316).jpg → Yawning (Drowsy) (Confidence: 286.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3317).jpg → Neutral (Drowsy) (Confidence: 313.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (34).png → Eyes Closed (Drowsy) (Confidence: 334.95%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3417).jpg → Yawning (Drowsy) (Confidence: 448.3%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ Drowsy (3418).jpg → Yawning (Drowsy) (Confidence: 368.15%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ✅ Drowsy (3419).jpg → Yawning (Drowsy) (Confidence: 300.98%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
# !pip install mediapipe

# %%
# ########---------------------------WORKIG ONE------------------------------------#######
# import cv2
# import numpy as np
# import mediapipe as mp
# import tensorflow as tf

# # **Load MediaPipe Face Mesh**
# mp_face_mesh = mp.solutions.face_mesh
# face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# # **Define class labels**
# CLASS_LABELS = {
#     0: "Eyes Closed",  # Drowsy
#     1: "Happy",        # Non-Drowsy
#     2: "Neutral",      # Non-Drowsy
#     3: "Yawning"       # Drowsy
# }

# # **Start the webcam**
# cap = cv2.VideoCapture(0)  # 0 for default camera

# # **Function to preprocess the frame for model input**
# def preprocess_frame(frame, target_size=(224, 224)):
#     img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     img = cv2.resize(img, target_size)
#     img = img / 255.0  # Normalize pixel values (0 to 1)
#     return np.expand_dims(img, axis=0)  # Add batch dimension

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("❌ Error: Unable to capture video")
#         break

#     # **Convert frame to RGB for MediaPipe**
#     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     results = face_mesh.process(rgb_frame)

#     if results.multi_face_landmarks:
#         for face_landmarks in results.multi_face_landmarks:
#             h, w, _ = frame.shape

#             # **Get eye landmarks (based on MediaPipe Face Mesh indices)**
#             left_eye_top = face_landmarks.landmark[159]  # Upper eyelid
#             left_eye_bottom = face_landmarks.landmark[145]  # Lower eyelid

#             right_eye_top = face_landmarks.landmark[386]  # Upper eyelid
#             right_eye_bottom = face_landmarks.landmark[374]  # Lower eyelid

#             # Convert normalized coordinates to pixels
#             left_eye_opening = int((left_eye_bottom.y - left_eye_top.y) * h)
#             right_eye_opening = int((right_eye_bottom.y - right_eye_top.y) * h)

#             # **Calculate average eye openness**
#             avg_eye_opening = (left_eye_opening + right_eye_opening) / 2

#             # **Get mouth landmarks**
#             upper_lip_top = face_landmarks.landmark[13]  
#             lower_lip_bottom = face_landmarks.landmark[14]  

#             upper_y = int(upper_lip_top.y * h)
#             lower_y = int(lower_lip_bottom.y * h)

#             # **Calculate mouth opening**
#             mouth_opening = lower_y - upper_y

#             # **Preprocess and predict using the model**
#             img_array = preprocess_frame(frame)
#             prediction = model.predict(img_array)
#             class_id = np.argmax(prediction)  # Get class index
#             confidence = round(max(prediction[0]) * 100, 2)  # Get highest probability

#             # **Drowsiness Classification Logic**
#             if avg_eye_opening < 5 or class_id == 0:  # If eyes are too closed OR model says eyes closed
#                 status = "Drowsy 😴 (Eyes Closed)"
#                 color = (0, 0, 255)  # Red for drowsy
#             elif mouth_opening > 15 and class_id == 3:  # If mouth is open + model says yawning
#                 status = "Drowsy 😴 (Yawning)"
#                 color = (0, 0, 255)
#             else:
#                 status = "Non-Drowsy 😊"
#                 color = (0, 255, 0)  # Green for non-drowsy

#             # **Display Results on Screen**
#             text = f"{CLASS_LABELS[class_id]} ({status}) - {confidence}%"
#             cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

#     # **Show Webcam Output**
#     cv2.imshow("Drowsiness Detection", frame)

#     # **Press 'q' to exit**
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # **Release resources**
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# # ########---------WORKING Perfectly----------#######

# %%
import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf

# **Load MediaPipe Face Mesh**
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# **Define class labels**
CLASS_LABELS = {
    0: "Eyes Closed",  # Drowsy
    1: "Happy",        # Non-Drowsy
    2: "Neutral",      # Non-Drowsy
    3: "Yawning"       # Drowsy
}

# **Start the webcam**
cap = cv2.VideoCapture(0)  # 0 for default camera

# **Function to preprocess the frame for model input**
def preprocess_frame(frame, target_size=(224, 224)):
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)
    img = img / 255.0  # Normalize pixel values (0 to 1)
    return np.expand_dims(img, axis=0)  # Add batch dimension

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Error: Unable to capture video")
        break

    # **Convert frame to RGB for MediaPipe**
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(rgb_frame)

    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            h, w, _ = frame.shape

            # **Get eye landmarks**
            left_eye_top = face_landmarks.landmark[159]  
            left_eye_bottom = face_landmarks.landmark[145]  
            right_eye_top = face_landmarks.landmark[386]  
            right_eye_bottom = face_landmarks.landmark[374]  

            # Convert normalized coordinates to pixels
            left_eye_opening = int((left_eye_bottom.y - left_eye_top.y) * h)
            right_eye_opening = int((right_eye_bottom.y - right_eye_top.y) * h)

            # **Set optimized eye openness threshold**
            eye_threshold = 5  # Adjust this based on testing

            # **Calculate average eye openness**
            avg_eye_opening = (left_eye_opening + right_eye_opening) / 2

            # **Get mouth landmarks**
            upper_lip_top = face_landmarks.landmark[13]  
            lower_lip_bottom = face_landmarks.landmark[14]  

            # Convert to pixels
            upper_y = int(upper_lip_top.y * h)
            lower_y = int(lower_lip_bottom.y * h)

            # **Calculate mouth opening**
            mouth_opening = lower_y - upper_y

            # **Preprocess and predict using the model**
            img_array = preprocess_frame(frame)
            prediction = model.predict(img_array)
            class_id = np.argmax(prediction)  # Get class index
            confidence = round(max(prediction[0]) * 100, 2)  # Get highest probability

            # **Drowsiness Classification Logic**
            if avg_eye_opening < eye_threshold or class_id == 0:
                status = "Drowsy 😴 (Eyes Closed)"
                color = (0, 0, 255)  # Red for drowsy
            elif mouth_opening > 15 and class_id == 3:
                status = "Drowsy 😴 (Yawning)"
                color = (0, 0, 255)
            else:
                status = "Non-Drowsy 😊"
                color = (0, 255, 0)  # Green for non-drowsy

            # **Display Results on Screen**
            text = f"{CLASS_LABELS[class_id]} ({status}) - {confidence}%"
            cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    # **Show Webcam Output**
    cv2.imshow("Drowsiness Detection", frame)

    # **Press 'q' to exit**
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# **Release resources**
cap.release()
cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# import tensorflow as tf

# # **Define class labels**
# CLASS_LABELS = {
#     0: "Eyes Closed",  # Drowsy
#     1: "Happy",        # Non-Drowsy
#     2: "Neutral",      # Non-Drowsy
#     3: "Yawning"       # Drowsy
# }

# # **Load Haarcascade Classifiers**
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
# eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")
# mouth_cascade = cv2.CascadeClassifier(r"D:\Major Project\Final Proper\haarcascade_mcs_mouth.xml")  # Mouth detection

# # **Check if mouth cascade is loaded**
# if mouth_cascade.empty():
#     print("❌ Error: Mouth cascade file not loaded! Check the file path.")
#     exit()
# else:
#     print("✅ Mouth cascade loaded successfully!")

# # **Start the webcam**
# cap = cv2.VideoCapture(0)  # 0 for default camera

# # **Function to preprocess the frame for model input**
# def preprocess_frame(frame, target_size=(224, 224)):
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     gray = cv2.equalizeHist(gray)  # Improve contrast
#     img = cv2.cvtColor(gray, cv2.COLOR_GRAY2RGB)  # Convert back to RGB
#     img = cv2.resize(img, target_size)
#     img = img / 255.0  # Normalize pixel values (0 to 1)
#     return np.expand_dims(img, axis=0)  # Add batch dimension

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("❌ Error: Unable to capture video")
#         break

#     # **Face detection**
#     faces = face_cascade.detectMultiScale(frame, scaleFactor=1.3, minNeighbors=5)
    
#     for (x, y, w, h) in faces:
#         roi_face = frame[y:y+h, x:x+w]  # Extract face region
        
#         # **Eye detection**
#         eyes = eye_cascade.detectMultiScale(roi_face)
        
#         # **Mouth detection (focus on lower 40% of the face)**
#         mouth_y_start = int(0.6 * h)  # Start from 60% down
#         mouth_region = roi_face[int(h * 0.4):h, :]
        
#         mouths = mouth_cascade.detectMultiScale(mouth_region, scaleFactor=1.1, minNeighbors=5)

#         # **Preprocess and predict using the model**
#         img_array = preprocess_frame(roi_face)
#         prediction = model.predict(img_array)
#         class_id = np.argmax(prediction)  # Get class index
#         confidence = round(max(prediction[0]) * 100, 2)  # Get highest probability

#         # **Debugging: Print raw predictions**
#         print(f"🔍 Raw Prediction: {prediction}")

#         # **Drowsiness Classification Logic**
#         if class_id in [0, 3]:  # Eyes Closed OR Yawning
#             status = "Drowsy 😴"
#             color = (0, 0, 255)  # Red for drowsy
#         else:
#             status = "Non-Drowsy 😊"
#             color = (0, 255, 0)  # Green for non-drowsy

#         # **Additional Check: If no eyes detected, assume Drowsy**
#         if len(eyes) == 0:
#             status = "Drowsy 😴 (Eyes Not Detected)"
#             color = (0, 0, 255)

#         # **Yawn Detection: If mouth is detected and model predicts 'Yawning'**
#         if len(mouths) > 0 and class_id == 3:
#             status = "Drowsy 😴 (Yawning Detected)"
#             color = (0, 0, 255)

#         # **Display Results on Screen**
#         text = f"{CLASS_LABELS[class_id]} ({status}) - {confidence}%"
#         cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
#         cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)

#     # **Show Webcam Output**
#     cv2.imshow("Drowsiness Detection", frame)

#     # **Press 'q' to exit**
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # **Release resources**
# cap.release()
# cv2.destroyAllWindows()
